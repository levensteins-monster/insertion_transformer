# %% [markdown]
# __this__ notebook fine-tunes a transformer pre-trained with `pretrain_enru_8gpu.ipynb` samplng trajectories from model. It requires all the same data files plus three more files generated by the pretrain notebook:
# * __`enru_base_pretrain/inp.voc`__ : english vocabulary containing all bpe tokens
# * __`enru_base_pretrain/out.voc`__ : russian vocabulary containing all bpe tokens
# * __`enru_base_pretrain/checkpoint_final.npz`__ : russian vocabulary containing all bpe tokens

# %%
import os, sys
sys.path.append('..')
import numpy as np
import tensorflow as tf
tf.reset_default_graph()
sess = tf.InteractiveSession(config=tf.ConfigProto(allow_soft_placement=True))

experiment_name = "enru_base_finetune"
# !rm -rf {experiment_name}
assert not os.path.exists(experiment_name), "please use unique name for each experiment"

# %% [markdown]
# ### Data preprocessing

# %%
from prefetch_generator import background
from lib.multi_gpu import ParallelBatchIterator
from lib.data import form_batches, form_adaptive_batches_windowed, \
                filter_by_len, cycle_shuffle, maxlen, linelen

class train:
    inp_lines = list(open('../../data/wmt_enru/train.en'))
    out_lines = list(open('../../data/wmt_enru/train.ru'))
    
    batcher = background(max_prefetch=256)(form_adaptive_batches_windowed)(
        filter_by_len(cycle_shuffle(zip(inp_lines, out_lines)), max_srclen=200, max_dstlen=200),
        max_size=2048, batch_size_max=256, split_len=10000,
    )
    parallel_batcher = background(max_prefetch=256)(ParallelBatchIterator)(batcher, 
                                     cost_func=lambda batch: max(linelen(pair[1]) for pair in batch) ** 2,
                                     n_buffers=8)
    
class dev:
    inp_lines = list(open('../../data/wmt_enru/dev.en'))
    out_lines = list(open('../../data/wmt_enru/dev.ru'))
    
    batcher = background(max_prefetch=256)(form_batches)(
        cycle_shuffle(zip(inp_lines, out_lines)),
        batch_size=256
    )

# %% [markdown]
# ### Model & vocabs

# %%
from lib.voc import Voc
inp_voc = Voc.load('./enru_base_pretrain/inp.voc')
out_voc = Voc.load('./enru_base_pretrain/out.voc')

# alternatively:
# inp_voc = Voc.from_sequences(train.inp_lines)
# out_voc = Voc.from_sequences(train.out_lines)

# %%
from lib.models import Transformer
from lib.multi_gpu import MultiGPUTrainer

hp = {
    'emb_size': 512,
    'hid_size': 512,
    'num_heads': 8,
    'ff_size': 2048,
    'num_layers': 6,
    'rescale_emb': True,
    'inp_emb_bias': False,
    'res_steps': 'nlda',
    'normalize_out': True,
    'attn_dropout': 0.0,
    'res_dropout': 0.1,
    'relu_dropout': 0.0,
    'share_emb': False,
}

make_model = lambda: Transformer('mod', inp_voc, out_voc, **hp)
trainer = MultiGPUTrainer(
    'trainer', make_model, optimizer_opts=dict(base_lr=5e-4, warmup_time=4000)
)
# Out:
# WARNING:tensorflow:From /home/jheuristic/.local/lib/python3.5/site-packages/tensorflow/python/ops/sparse_ops.py:1165: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# /home/jheuristic/.local/lib/python3.5/site-packages/tensorflow/python/ops/gradients_impl.py:112: UserWarning: Converting sparse IndexedSlices to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "Converting sparse IndexedSlices to a dense Tensor of unknown shape. "

# %%
from lib.saveload import save, load
sess.run(tf.global_variables_initializer())
load('enru_base_pretrain/checkpoint_final.npz', tf.trainable_variables())

# %%
import nltk
from lib.inference import BeamSearchInserts
model = trainer.master_model
decoder = BeamSearchInserts(model)

def compute_bleu(batch, beam_size=32, beam_spread=50, len_alpha=1.0, 
                 maxlen=lambda inp_line: len(inp_line.split()) * 2 + 3, unbpe=True):
    """
    Computes corpora-level bleu on batch.
    Note: this isn't exactly the same BLEU as what's used for model evaluation, but very close to one.
        Use moses BLEU for final evaluation.
    """
    translations, references = [], []
    for inp, ref_out in batch:
        hypo_scores = decoder.translate_line(inp, beam_size=beam_size, beam_spread=beam_spread,
                                             max_steps=maxlen(inp))
        hypo_scores = decoder.apply_length_penalty(hypo_scores, len_alpha=len_alpha)
        best_trans = max(hypo_scores.keys(), key=hypo_scores.get)
        if unbpe:
            best_trans = best_trans.replace('@@ ', '').replace(' `', '')
            ref_out = ref_out.replace('@@ ', '').replace(' `', '')
            
        translations.append(best_trans)
        references.append(ref_out)
    
    return nltk.bleu_score.corpus_bleu(
        [[ref.split()] for ref in references], 
        [trans.split() for trans in translations])

# %%
hypo_scores = decoder.translate_line('i am the monument to all your sins .',
                                     beam_size=4, beam_spread=50, verbose=True)
hypo_scores = decoder.apply_length_penalty(hypo_scores, len_alpha=1.0)
max(hypo_scores.keys(), key=hypo_scores.get)
# Out:
# -0.192589 .
# -0.796863 я .
# -1.098431 я гре .
# -1.554003 я гре `хам .
# -1.972841 я памятник гре `хам .
# -3.171587 я памятник тво гре `хам .
# -3.195140 я памятник тво `им гре `хам .
# -4.924546 я памятник всем тво `им гре `хам .
# -7.959128 я - памятник всем тво `им гре `хам .
# -12.040295 я - это памятник всем тво `им гре `хам .
# -18.457991 - я - это памятник всем тво `им гре `хам .
# -23.572369 я - я - это памятник всем тво `им гре `хам .
# -29.681389 - я - я - это памятник всем тво `им гре `хам .
# -35.520638 - , я - я - это памятник всем тво `им гре `хам .
# -38.374775 - , , я - я - это памятник всем тво `им гре `хам .
# -41.715313 - , , , я - я - это памятник всем тво `им гре `хам .
# -45.267685 - , , , , я - я - это памятник всем тво `им гре `хам .
# -48.861462 - , , , , - я - я - это памятник всем тво `им гре `хам .
# -52.530563 - , , , , , - я - я - это памятник всем тво `им гре `хам .
# 'я памятник тво `им гре `хам .'

# %%
from IPython.display import clear_output
import matplotlib.pyplot as plt
# %matplotlib inline
from tensorboardX import SummaryWriter
import pandas as pd
ewma = lambda x, span: pd.DataFrame({'x': x})['x'].ewm(span=span).mean().values

loss_history, acc_history, dev_bleu_history = [], [], []
writer = SummaryWriter(log_dir=experiment_name)

# %%
from itertools import chain
from tqdm import trange

for t in trange(100000):
    batches = chain(*[next(train.parallel_batcher) for _ in range(2)])
    metrics_t = trainer.train_on_batches(batches, slice_max_len=4600, optimizer_step=True)
    step = metrics_t['step']
    
    for key in metrics_t:
        writer.add_scalar(key, metrics_t[key], global_step=metrics_t['step'])
    loss_history.append(metrics_t['loss'])
    acc_history.append(metrics_t['acc'])
    
    if step % 100 == 0:
        dev_bleu_t = compute_bleu(next(dev.batcher))
        dev_bleu_history.append([len(loss_history), dev_bleu_t])
        writer.add_scalar('dev_BLEU', dev_bleu_t, global_step=step)
    
    if step % 5000 == 0:
        save(os.path.join(experiment_name, 'checkpoint_%i.npz' % step),
             [var for var in tf.get_collection(tf.GraphKeys.GLOBAL_VARIABLES) if 
              var.name.startswith('trainer/worker_0') or not var.name.startswith('trainer/worker')])
        
    if step % 100 == 0:
        clear_output(True)
        plt.figure(figsize=[18, 6])
        plt.subplot(1, 3, 1)
        plt.scatter(np.arange(len(loss_history)), loss_history, alpha=0.1)
        plt.plot(ewma(loss_history, span=100), color='orange')
        plt.title('train loss'); plt.grid()
        
        plt.subplot(1, 3, 2)
        plt.scatter(np.arange(len(acc_history)), acc_history, alpha=0.1)
        plt.plot(ewma(acc_history, span=100), color='orange')
        plt.title('train acc'); plt.grid()
        
        plt.subplot(1, 3, 3)
        dev_bleu_steps, dev_bleu_values = zip(*dev_bleu_history)
        plt.scatter(dev_bleu_steps, dev_bleu_values, alpha=0.1)
        plt.plot(dev_bleu_steps, ewma(dev_bleu_values, span=10), color='orange')
        plt.title('dev bleu'); plt.grid();
        plt.show()
# Out:
#   9%|▉         | 9300/100000 [95:59:21<1448:40:42, 57.50s/it]
#   9%|▉         | 9301/100000 [96:00:09<1379:43:18, 54.76s/it]
# KeyboardInterrupt:
